# %% [markdown]
# # Text Summarizing of articles

# %% [markdown]
# ## Text-Summarization
# **Automatic summarization** is the process of shortening a text document with software, in order to create a summary with the major points of the original document. Technologies that can make a coherent summary take into account variables such as length, writing style and syntax.
#
# Automatic data summarization is part of the real machine learning and data mining. The main idea of summarization is to find a subset of data which contains the "information" of the entire set. Such techniques are widely used in industry today. Search engines are an example; others include summarization of documents, image collections and videos. Document summarization tries to create a representative summary or abstract of the entire document, by finding the most informative sentences, while in image summarization the system finds the most representative and important (i.e. salient) images. For surveillance videos, one might want to extract the important events from the uneventful context.
#
# There are two general approaches to automatic summarization: Extraction and Abstraction.
# 1. *Extractive Summarization*: These methods rely on extracting several parts, such as phrases and sentences, from a piece of text and stack them together to create a summary. Therefore, identifying the right sentences for summarization is of utmost importance in an extractive method.
# 2. *Abstractive Summarization*: These methods use advanced NLP techniques to generate an entirely new summary. Some parts of this summary may not even appear in the original text. Such a summary might include verbal innovations.
# Research to date has focused primarily on extractive methods, which are appropriate for image collection summarization and video summarization.
#
# In this Jupyter notebook, TextRank algorithm for extractive text summarization is implemented using Google's PageRank search algorithm to generate corelations among sentences.
#
# ### Libraries Used
# - [Numpy](http://www.numpy.org)
# - [Pandas](https://pandas.pydata.org/)
# - [Natural Language Toolkit](https://www.nltk.org/)
#
# ### Algorithms and Concepts
# - TextRank
# - [PageRank](https://en.wikipedia.org/wiki/PageRank)
# - [Cosine Similarity](https://en.wikipedia.org/wiki/Cosine_similarity)
#
# ### How to run
# - Install the required libraries using pip, virtual environment or conda.
# - Run `jupyter notebook` in your terminal.

# %%
# Importing the required Libraries
import numpy as np
import pandas as pd
import nltk
# nltk.download('punkt') # one time execution
import re
#nltk.download('stopwords') # one time execution
import matplotlib.pyplot as plt

from nltk.tokenize import sent_tokenize

from nltk.corpus import stopwords

from sklearn.metrics.pairwise import cosine_similarity

import networkx as nx

# %%
# Extract word vectors
word_embeddings = {}
file = open(r'C:\Users\Vaishaali\Desktop\glove.6B.100d.txt', encoding='utf-8')
for line in file:
    values = line.split()
    word = values[0]
    coefs = np.asarray(values[1:], dtype='float32')
    word_embeddings[word] = coefs
file.close()
len(word_embeddings)
# Out:
# 400000

# %%
# reading the file
df = pd.read_excel(r'C:\Users\Vaishaali\Desktop\TASK.xlsx')

# %%
df
# Out:
#       TEST DATASET                                         Unnamed: 1
# 0              NaN                                       Introduction
# 1              NaN  Acnesol Gel is an antibiotic that fights bacte...
# 2              NaN  Ambrodil Syrup is used for treating various re...
# 3              NaN  Augmentin 625 Duo Tablet is a penicillin-type ...
# 4              NaN  Azithral 500 Tablet is an antibiotic used to t...
# ...            ...                                                ...
# 996            NaN  Azapure Tablet belongs to a group of medicines...
# 997            NaN  Arimidex 1mg Tablet  is used alone or with oth...
# 998            NaN  Arpimune ME 100mg Capsule is used to prevent y...
# 999            NaN  Amlodac CH Tablet is a combination medicine us...
# 1000           NaN  Angizem CD 120 Capsule ER is used to treat ang...
#
# [1001 rows x 2 columns]

# %%
df.columns
# Out:
# Index(['TEST DATASET', 'Unnamed: 1'], dtype='object')

# %%
df.rename(columns = {'Unnamed: 1' : 'Introduction' }, inplace=True)
# Deleting the first row
df.drop(0)
# Out:
#       TEST DATASET                                       Introduction
# 1              NaN  Acnesol Gel is an antibiotic that fights bacte...
# 2              NaN  Ambrodil Syrup is used for treating various re...
# 3              NaN  Augmentin 625 Duo Tablet is a penicillin-type ...
# 4              NaN  Azithral 500 Tablet is an antibiotic used to t...
# 5              NaN  Alkasol Oral Solution is a medicine used in th...
# ...            ...                                                ...
# 996            NaN  Azapure Tablet belongs to a group of medicines...
# 997            NaN  Arimidex 1mg Tablet  is used alone or with oth...
# 998            NaN  Arpimune ME 100mg Capsule is used to prevent y...
# 999            NaN  Amlodac CH Tablet is a combination medicine us...
# 1000           NaN  Angizem CD 120 Capsule ER is used to treat ang...
#
# [1000 rows x 2 columns]

# %%
# Converting the DataFrame into a dictionary
text_dictionary = {}
for i in range(1,len(df['TEST DATASET'])):
    text_dictionary[i] = df['Introduction'][i]
    
print(text_dictionary[1])
# Out:
# Acnesol Gel is an antibiotic that fights bacteria. It is used to treat acne, which appears as spots or pimples on your face, chest or back. This medicine works by attacking the bacteria that cause these pimples.Acnesol Gel is only meant for external use and should be used as advised by your doctor. You should normally wash and dry the affected area before applying a thin layer of the medicine. It should not be applied to broken or damaged skin. Avoid any contact with your eyes, nose, or mouth. Rinse it off with water if you accidentally get it in these areas. It may take several weeks for your symptoms to improve, but you should keep using this medicine regularly. Do not stop using it as soon as your acne starts to get better. Ask your doctor when you should stop treatment.Common side effects like minor itching, burning, or redness of the skin and oily skin may be seen in some people. These are usually temporary and resolve on their own. Consult your doctor if they bother you or do not go away.It is a safe medicine, but you should inform your doctor if you have any problems with your bowels (intestines). Also, inform the doctor if you have ever had bloody diarrhea caused by taking antibiotics or if you are using any other medicines to treat skin conditions. Consult your doctor about using this medicine if you are pregnant or breastfeeding.

# %% [markdown]
# **There are 1000 such description of the different medicines. The task is to give summarized form of these descriptions.**

# %%
# function to remove stopwords
def remove_stopwords(sen):
    stop_words = stopwords.words('english')
    
    sen_new = " ".join([i for i in sen if i not in stop_words])
    return sen_new

# %%
# function to make vectors out of the sentences
def sentence_vector_func (sentences_cleaned) : 
    sentence_vector = []
    for i in sentences_cleaned:
        if len(i) != 0:
            v = sum([word_embeddings.get(w, np.zeros((100,))) for w in i.split()])/(len(i.split())+0.001)
        else:
            v = np.zeros((100,))
        sentence_vector.append(v)
    
    return (sentence_vector)

# %%
# function to get the summary of the articles
# NOTE - Remove '#' infront of print statement for displaying the contents at different stages of the text summarization process
def summary_text (test_text, n = 5):
    sentences = []
    
    # tokenising the text 
    sentences.append(sent_tokenize(test_text))
    # print(sentences)
    sentences = [y for x in sentences for y in x] # flatten list
    # print(sentences)
    
    # remove punctuations, numbers and special characters
    clean_sentences = pd.Series(sentences).str.replace("[^a-z A-Z 0-9]", " ")

    # make alphabets lowercase
    clean_sentences = [s.lower() for s in clean_sentences]
    #print(clean_sentences)

    
    # remove stopwords from the sentences
    clean_sentences = [remove_stopwords(r.split()) for r in clean_sentences]
    #print(clean_sentences)
    
    sentence_vectors = sentence_vector_func(clean_sentences)
    
    # similarity matrix
    sim_mat = np.zeros([len(sentences), len(sentences)])
    #print(sim_mat)
    
    # Finding the similarities between the sentences 
    for i in range(len(sentences)):
        for j in range(len(sentences)):
            if i != j:
                sim_mat[i][j] = cosine_similarity(sentence_vectors[i].reshape(1,100), sentence_vectors[j].reshape(1,100))[0,0]
    
    
    nx_graph = nx.from_numpy_array(sim_mat)
    scores = nx.pagerank(nx_graph)
    #print(scores)
    
    ranked_sentences = sorted(((scores[i],s) for i,s in enumerate(sentences)))
    # Extract sentences as the summary
    summarised_string = ''
    for i in range(n):
        
        try:
            summarised_string = summarised_string + str(ranked_sentences[i][1])            
        except IndexError:
            print ("Summary Not Available")
    
    return (summarised_string)

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Vaishaali\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
print("Kindly let me know in how many sentences you want the summary - ")
x = int(input())

summary_dictionary = {}

for key in text_dictionary:
    
    para = text_dictionary[key]
    print("Summary of the article - ",key)
    summary = summary_text(para,x)
    summary_dictionary[key] = summary
    
    print(summary)
    print('='*120)    
    
print ("*"*40,"The process has been completed successfully","*"*40)
# Out:
# Kindly let me know in how many sentences you want the summary -
# 1
# Summary of the article -  1
# Acnesol Gel is an antibiotic that fights bacteria.
# ========================================================================================================================
# Summary of the article -  2
# Ambrodil Syrup is used for treating various respiratory tract disorders associated with excessive mucus.
# ========================================================================================================================
# Summary of the article -  3
# It is used to treat infections of the lungs (e.g., pneumonia), ear, nasal sinus, urinary tract, skin and soft tissue.
# ========================================================================================================================
# Summary of the article -  4
# These are usually temporary and subside with the completion of treatment.
# ========================================================================================================================
# Summary of the article -  5
# This will prevent you from getting an upset stomach.
# ========================================================================================================================
# Summary of the article -  6
# Allegra 120mg Tablet belongs to a group of medicines called antihistamines.
# ========================================================================================================================
# Summary of the article -  7
# It thins mucus in the nose, windpipe and lungs, making it easier to cough out.
# ========================================================================================================================
# Summary of the article -  8
# This medicine should relieve indigestion and heartburn within a few hours.
# ========================================================================================================================
# Summary of the article -  9
# Inform your doctor if you are pregnant, or breastfeeding.
# ========================================================================================================================
# Summary of the article -  10
# These are usually temporary and subside with the completion of treatment.
# ========================================================================================================================
# Summary of the article -  11
# Aciloc RD 20 Tablet is a prescription medicine used to treat gastroesophageal reflux disease (Acid reflux) and peptic ulcer disease by relieving the symptoms such as heartburn, stomach pain, or irritation.
# ========================================================================================================================
# Summary of the article -  12
# It is used to treat fungal infections of the skin.
# ========================================================================================================================
# Summary of the article -  13
# Inform your doctor if you are pregnant, or breastfeeding.
# ========================================================================================================================
# Summary of the article -  14
# Altraday Capsule SR is a combination of two medicines.
# ========================================================================================================================
# Summary of the article -  15
# It is for external use only.
# ========================================================================================================================
# Summary of the article -  16
# It also relaxes the muscles in your airway.
# ========================================================================================================================
# Summary of the article -  17
# Most of these are temporary and usually resolve with time.
# ========================================================================================================================
# Summary of the article -  18
# It relieves allergic symptoms such as sneezing, runny nose, watery eyes, and throat irritation.
# ========================================================================================================================
# Summary of the article -  19
# It lowers the blood pressure by relaxing the blood vessels.
# ========================================================================================================================
# Summary of the article -  20
# It reduces the formation of harmful blood clots in blood vessels.
# ========================================================================================================================
# Summary of the article -  21
# Consult your doctor if you are breastfeeding mother.
# ========================================================================================================================
# Summary of the article -  22
# If it gets into your eyes, nose, mouth, or vagina rinse with water.
# ========================================================================================================================
# Summary of the article -  23
# It relieves allergic symptoms such as sneezing, runny nose, watery eyes, and throat irritation.
# ========================================================================================================================
# Summary of the article -  24
# It relieves watery eyes, runny nose, sneezing, and itching.Allegra 180mg Tablet should be taken empty stomach.
# ========================================================================================================================
# Summary of the article -  25
# Pregnant or breastfeeding women should also consult their doctor for advice before taking this medicine.
# ========================================================================================================================
# Summary of the article -  26
# Ativan 2mg Tablet is a prescription medicine used to treat anxiety disorders such as generalized anxiety disorder (excessive worry or restlessness), obsessive compulsive disorder (OCD), panic attacks and social phobias.
# ========================================================================================================================
# Summary of the article -  27
# Inform your doctor if you are pregnant, or breastfeeding.
# ========================================================================================================================
# Summary of the article -  28
# It is an effective appetite stimulant.
# ========================================================================================================================
# Summary of the article -  29
# It relieves allergic symptoms such as sneezing, runny nose, watery eyes, and throat irritation.
# ========================================================================================================================
# Summary of the article -  30
# If you experience any allergic reaction (rashes, itching, swelling, shortness of breath, etc.
# ========================================================================================================================
# Summary of the article -  31
# Alprax 0.25 Tablet belongs to a class of medicines known as benzodiazepines.
# ========================================================================================================================
# Summary of the article -  32
# Follow your doctor’s instructions.
# ========================================================================================================================
# Summary of the article -  33
# It reduces the swelling (edema) caused by some other conditions.
# ========================================================================================================================
# Summary of the article -  34
# AF Kit Tablet is a combination medicine used in syndromic management of vaginal discharge.
# ========================================================================================================================
# Summary of the article -  35
# Swallow it as a whole,  do not crush, chew, break, or open them.
# ========================================================================================================================
# Summary of the article -  36
# It is used to treat infections of the lungs (e.g., pneumonia), ear, nasal sinus, urinary tract, skin and soft tissue.
# ========================================================================================================================
# Summary of the article -  37
# Common side effects of this medicine include constipation, flatulence, dyspepsia, and abdominal pain.
# ========================================================================================================================
# Summary of the article -  38
# Amlokind 5 Tablet belongs to a class of medicines known as a calcium channel blockers.
# ========================================================================================================================
# Summary of the article -  39
# AB Phylline Capsule is used to treat and prevent symptoms of asthma and chronic obstructive pulmonary disorder (a lung disorder in which flow of air to the lung is blocked).
# ========================================================================================================================
# Summary of the article -  40
# It’s used to treat the symptoms of asthma and chronic obstructive pulmonary disease (COPD) such as coughing, wheezing and breathlessness.Asthalin 100mcg Inhaler is called "reliever" inhalers because they give you quick relief from breathing problems when you need it.
# ========================================================================================================================
# Summary of the article -  41
# Alfoo 10mg Tablet PR is an alpha adrenergic antagonist that is used in the treatment of benign prostatic hyperplasia.
# ========================================================================================================================
# Summary of the article -  42
# Alprax 0.5mg Tablet SR belongs to a class of medicines known as benzodiazepines.
# ========================================================================================================================
# Summary of the article -  43
# It is used to treat infections of the lungs (e.g., pneumonia), ear, nasal sinus, urinary tract, skin and soft tissue.
# ========================================================================================================================
# Summary of the article -  44
# Most of these are temporary and usually resolve with time.
# ========================================================================================================================
# Summary of the article -  45
# Acitrom 2 Tablet is an oral anticoagulant which helps to prevent formation of harmful blood clots in the legs, lungs, brain and heart.
# ========================================================================================================================
# Summary of the article -  46
# It works effectively to reduce abdominal pain and cramps by relaxing the muscles of the stomach and gut.
# ========================================================================================================================
# Summary of the article -  47
# It thins mucus in the nose, windpipe and lungs, making it easier to cough out.
# ========================================================================================================================
# Summary of the article -  48
# These are usually temporary and subside with the completion of treatment.
# ========================================================================================================================
# Summary of the article -  49
# Inform your doctor if you are pregnant, or breastfeeding.
# ========================================================================================================================
# Summary of the article -  50
# Asthalin Syrup is used to relieve symptoms of asthma and chronic obstructive pulmonary disease (COPD) such as coughing, wheezing and breathlessness.
# ========================================================================================================================
# Summary of the article -  51
# It minimizes oil production and helps to reduce inflammation.
# ========================================================================================================================
# Summary of the article -  52
# Inform your doctor if you are pregnant, or breastfeeding.
# ========================================================================================================================
# Summary of the article -  53
# Common side effects of this medicine include constipation, flatulence, dyspepsia, and abdominal pain.
# ========================================================================================================================
# Summary of the article -  54
# It might lower down the level of calcium, sodium and magnesium in the blood.
# ========================================================================================================================
# Summary of the article -  55
# If you experience any allergic reaction (rashes, itching, swelling, shortness of breath, etc.
# ========================================================================================================================
# Summary of the article -  56
# Most of these are temporary and usually resolve with time.
# ========================================================================================================================
# Summary of the article -  57
# It is effective in most infections of the respiratory tract, ear, nose, throat, lungs, and skin.
# ========================================================================================================================
# Summary of the article -  58
# Ativan 1mg Tablet is a prescription medicine used to treat anxiety disorders such as generalized anxiety disorder (excessive worry or restlessness), obsessive compulsive disorder (OCD), panic attacks and social phobias.
# ========================================================================================================================
# Summary of the article -  59
# It is used to reduce pain and inflammation in conditions like rheumatoid arthritis, ankylosing spondylitis, and osteoarthritis.
# ========================================================================================================================
# Summary of the article -  60
# Alaspan Tablet belongs to a group of medicines called antihistamines.
# ========================================================================================================================
# Summary of the article -  61
# It should be taken just before or with the first meal of the day.
# ========================================================================================================================
# Summary of the article -  62
# If it gets into your eyes, nose, mouth, or vagina rinse with water.
# ========================================================================================================================
# Summary of the article -  63
# If you experience any allergic reaction (rashes, itching, swelling, shortness of breath, etc.
# ========================================================================================================================
# Summary of the article -  64
# Most of these are temporary and usually resolve with time.
# ========================================================================================================================
# Summary of the article -  65
# Amlong Tablet belongs to a class of medicines known as a calcium channel blockers.
# ========================================================================================================================
# Summary of the article -  66
# Acemiz-S Tablet is not recommended if you are pregnant or breastfeeding.
# ========================================================================================================================
# Summary of the article -  67
# It is used to treat infections of the lungs (e.g., pneumonia), ear, nasal sinus, urinary tract, skin and soft tissue.
# ========================================================================================================================
# Summary of the article -  68
# It thins mucus in the nose, windpipe and lungs, making it easier to cough out.
# ========================================================================================================================
# Summary of the article -  69
# It thins mucus in the nose, windpipe and lungs, making it easier to cough out.
# ========================================================================================================================
# Summary of the article -  70
# It helps in treating viral infections like herpes labialis, herpes simplex, shingles, genital herpes infection, and chickenpox.
# ========================================================================================================================
# Summary of the article -  71
# It may be increased gradually.
# ========================================================================================================================
# Summary of the article -  72
# It thins mucus in the nose, windpipe and lungs, making it easier to cough out.
# ========================================================================================================================
# Summary of the article -  73
# Pregnant or breastfeeding mothers should consult their doctor before using this medicine.
# ========================================================================================================================
# Summary of the article -  74
# AF 400 Tablet belongs to a group of medicines called antifungals.
# ========================================================================================================================
# Summary of the article -  75
# It should be used in the dose and duration as directed by your doctor.
# ========================================================================================================================
# Summary of the article -  76
# It is used to reduce pain and inflammation in conditions like rheumatoid arthritis, ankylosing spondylitis, and osteoarthritis.
# ========================================================================================================================
# Summary of the article -  77
# It is effective in infections of the throat, ear, nasal sinuses, respiratory tract (eg.
# ========================================================================================================================
# Summary of the article -  78
# Ace-Proxyvon CR Tablet is a combination of two medicines.
# ========================================================================================================================
# Summary of the article -  79
# You should take it regularly to get the most benefit from it.
# ========================================================================================================================
# Summary of the article -  80
# Anal fissure
# ========================================================================================================================
# Summary of the article -  81
# If it gets into your eyes, nose, or mouth rinse with water.
# ========================================================================================================================
# Summary of the article -  82
# Acivir Cream is an antiviral medicine which helps in treating skin infections caused by Herpes simplex virus such as herpes labialis.
# ========================================================================================================================
# Summary of the article -  83
# Aten 50 Tablet belongs to a group of medicines called beta-blockers.
# ========================================================================================================================
# Summary of the article -  84
# It may not be suitable.
# ========================================================================================================================
# Summary of the article -  85
# It thins mucus in the nose, windpipe and lungs, making it easier to cough out.
# ========================================================================================================================
# Summary of the article -  86
# These are usually temporary and subside with the completion of treatment.
# ========================================================================================================================
# Summary of the article -  87
# If you are affected by dizziness, avoid driving.
# ========================================================================================================================
# Summary of the article -  88
# Amlodac 5 Tablet belongs to a class of medicines known as a calcium channel blockers.
# ========================================================================================================================
# Summary of the article -  89
# The dose and duration will depend on the severity of your condition.
# ========================================================================================================================
# Summary of the article -  90
# These are usually temporary and subside with the completion of treatment.
# ========================================================================================================================
# Summary of the article -  91
# It kills the tiny insects (mites) and their eggs.
# ========================================================================================================================
# Summary of the article -  92
# AB Phylline SR 200 Tablet is used to treat and prevent symptoms of asthma and chronic obstructive pulmonary disorder (a lung disorder in which flow of air to the lung is blocked).
# ========================================================================================================================
# Summary of the article -  93
# It thins the mucus in the nose and windpipe, making it easier to cough out.
# ========================================================================================================================
# Summary of the article -  94
# Acogut Tablet is used in the treatment of indigestion.
# ========================================================================================================================
# Summary of the article -  95
# Allegra Suspension Raspberry & Vanilla belongs to a group of medicines called antihistamines.
# ========================================================================================================================
# Summary of the article -  96
# AB-Flo Capsule is used to treat and prevent symptoms of asthma and chronic obstructive pulmonary disorder (a lung disorder in which flow of air to the lung is blocked).
# ========================================================================================================================
# Summary of the article -  97
# It is used to reduce pain and inflammation in conditions like rheumatoid arthritis, ankylosing spondylitis, and osteoarthritis.
# ========================================================================================================================
# Summary of the article -  98
# Pregnant or breastfeeding women should also consult their doctor for advice before taking this medicine.
# ========================================================================================================================
# Summary of the article -  99
# It is effective in most infections of the respiratory tract, ear, nose, throat, lungs, and skin.
# ========================================================================================================================
# Summary of the article -  100
# AF 150 Tablet DT belongs to a group of medicines called antifungals.
# ========================================================================================================================
# Summary of the article -  101
# This medicine should relieve indigestion and heartburn within a few hours.
# ========================================================================================================================
# Summary of the article -  102
# It is used to treat pain and inflammation in conditions like rheumatoid arthritis, ankylosing spondylitis, and osteoarthritis.
# ========================================================================================================================
# Summary of the article -  103
# Anxit 0.5 Tablet belongs to a class of medicines known as benzodiazepines.
# ========================================================================================================================
# Summary of the article -  104
# It is used to treat infections of the lungs (e.g., pneumonia), ear, nasal sinus, urinary tract, skin, and soft tissue.
# ========================================================================================================================
# Summary of the article -  105
# It relieves watery eyes, runny nose, sneezing, and itching.Alerid Tablet can be taken with or without food.
# ========================================================================================================================
# Summary of the article -  106
# It may not be suitable.
# ========================================================================================================================
# Summary of the article -  107
# Avil Injection is an antiallergic medication.
# ========================================================================================================================
# Summary of the article -  108
# It is effective in infections of the throat, ear, nasal sinuses, respiratory tract (eg.
# ========================================================================================================================
# Summary of the article -  109
# It relieves allergic symptoms such as sneezing, running nose, watery eyes, itching, swelling, and congestion or stiffness.
# ========================================================================================================================
# Summary of the article -  110
# If you experience any allergic reaction (rashes, itching, swelling, shortness of breath, etc.
# ========================================================================================================================
# Summary of the article -  111
# It relieves allergic symptoms such as sneezing, runny nose, watery eyes, and throat irritation.
# ========================================================================================================================
# Summary of the article -  112
# The dose will be decided by your doctor.
# ========================================================================================================================
# Summary of the article -  113
# AB-Flo-N Tablet is used for the prevention of chronic obstructive pulmonary disorder (a lung disorder in which the flow of air to the lungs is blocked).
# ========================================================================================================================
# Summary of the article -  114
# Acitrom 1 Tablet is an oral anticoagulant which helps to prevent formation of harmful blood clots in the legs, lungs, brain and heart.
# ========================================================================================================================
# Summary of the article -  115
# It kills the tiny insects (mites) and their eggs.
# ========================================================================================================================
# Summary of the article -  116
# Amlovas 5 Tablet belongs to a class of medicines known as a calcium channel blockers.
# ========================================================================================================================
# Summary of the article -  117
# It thins mucus in the nose, windpipe and lungs, making it easier to cough out.
# ========================================================================================================================
# Summary of the article -  118
# Avamys Nasal Spray is a steroid.
# ========================================================================================================================
# Summary of the article -  119
# Aten 25 Tablet belongs to a group of medicines called beta-blockers.
# ========================================================================================================================
# Summary of the article -  120
# Aziderm 20% Cream is a topical medication used in the treatment of acne (pimples).
# ========================================================================================================================
# Summary of the article -  121
# Inform your doctor if you are pregnant, planning pregnancy or breastfeeding.
# ========================================================================================================================
# Summary of the article -  122
# Aerocort Inhaler is used in the treatment of asthma (wheezing and shortness of breath).
# ========================================================================================================================
# Summary of the article -  123
# Aziderm 10% Cream is a topical medication used in the treatment of acne (pimples).
# ========================================================================================================================
# Summary of the article -  124
# These are usually temporary and subside with the completion of treatment.
# ========================================================================================================================
# Summary of the article -  125
# If you experience any allergic reaction (rashes, itching, swelling, shortness of breath, etc.
# ========================================================================================================================
# Summary of the article -  126
# Acuvin Tablet is a pain relieving medicine.
# ========================================================================================================================
# Summary of the article -  127
# Asthalin 4 Tablet is used to relieve symptoms of asthma and chronic obstructive pulmonary disease (COPD) such as coughing, wheezing and breathlessness.
# ========================================================================================================================
# Summary of the article -  128
# Alkacip Syrup is a medicine used in the treatment of gout and kidney stones.
# ========================================================================================================================
# Summary of the article -  129
# It should be taken just before or with the first meal of the day.
# ========================================================================================================================
# Summary of the article -  130
# Aprezo Tablet is used in the treatment of moderate to severe plaque psoriasis which is a type of skin condition.
# ========================================================================================================================
# Summary of the article -  131
# It kills the bacteria which cause acne.
# ========================================================================================================================
# Summary of the article -  132
# Acnesol 1% solution is an antibiotic that fights bacteria.
# ========================================================================================================================
# Summary of the article -  133
# Also, pregnant women and breastfeeding mothers should consult doctor before taking it.
# ========================================================================================================================
# Summary of the article -  134
# Amortive Cream is an antifungal medication.
# ========================================================================================================================
# Summary of the article -  135
# It reduces the swelling (edema) caused by some other conditions.
# ========================================================================================================================
# Summary of the article -  136
# It relieves allergic symptoms such as sneezing, runny nose, watery eyes, and throat irritation.
# ========================================================================================================================
# Summary of the article -  137
# Ambrolite Syrup is used for treating various respiratory tract disorders associated with excessive mucus.
# ========================================================================================================================
# Summary of the article -  138
# Pregnant or breastfeeding women should also consult their doctor for advice before taking this medicine.
# ========================================================================================================================
# Summary of the article -  139
# Alkacitral Liquid is a medicine used in the treatment of gout and kidney stones.
# ========================================================================================================================
# Summary of the article -  140
# Alex Cough Lozenges Lemon Ginger is an antitussive medicine.
# ========================================================================================================================
# Summary of the article -  141
# Amantrel Capsule is used alone, or with other medicines to treat Parkinson’s disease.
# ========================================================================================================================
# Summary of the article -  142
# It thins mucus in the nose, windpipe and lungs, making it easier to cough out.
# ========================================================================================================================
# Summary of the article -  143
# These are usually temporary and subside with the completion of treatment.
# ========================================================================================================================
# Summary of the article -  144
# Do not use a bottle if the seal is broken before you open it.
# ========================================================================================================================
# Summary of the article -  145
# Ageless Tablet is a prescription medicine.
# ========================================================================================================================
# Summary of the article -  146
# Amrolstar Cream is an antifungal medication.
# ========================================================================================================================
# Summary of the article -  147
# It may not be suitable.
# ========================================================================================================================
# Summary of the article -  148
# The dose and duration will depend on the severity of your condition.
# ========================================================================================================================
# Summary of the article -  149
# It relieves allergic symptoms such as sneezing, runny nose, watery eyes, and throat irritation.
# ========================================================================================================================
# Summary of the article -  150
# It minimizes oil production and helps to reduce inflammation.
# ========================================================================================================================
# Summary of the article -  151
# Ascoril D 12 Oral Suspension Orange is an antitussive medicine.
# ========================================================================================================================
# Summary of the article -  152
# Actapro Tablet is used in the treatment of indigestion.
# ========================================================================================================================
# Summary of the article -  153
# Atorva Tablet belongs to a group of medicines called statins.
# ========================================================================================================================
# Summary of the article -  154
# It is used to treat infections of the lungs (e.g., pneumonia), ear, nasal sinus, urinary tract, skin and soft tissue.
# ========================================================================================================================
# Summary of the article -  155
# Inform your doctor if you are pregnant, or breastfeeding.
# ========================================================================================================================
# Summary of the article -  156
# If you are affected by dizziness, avoid driving.
# ========================================================================================================================
# Summary of the article -  157
# It relieves allergy symptoms such as runny nose, stuffy nose, sneezing, watery eyes and congestion or stuffiness.
# ========================================================================================================================
# Summary of the article -  158
# It helps in treating viral infections like herpes labialis, herpes simplex, shingles, genital herpes infection, and chickenpox.
# ========================================================================================================================
# Summary of the article -  159
# Alcros 200 Capsule belongs to a group of medicines called antifungals.
# ========================================================================================================================
# Summary of the article -  160
# Common side effects of this medicine include constipation, flatulence, dyspepsia, and abdominal pain.
# ========================================================================================================================
# Summary of the article -  161
# It relieves allergic symptoms such as sneezing, runny nose, watery eyes, and throat irritation.
# ========================================================================================================================
# Summary of the article -  162
# If it gets into your eyes, nose, mouth, or vagina rinse with water.
# ========================================================================================================================
# Summary of the article -  163
# It is used to treat infections of the lungs (e.g., pneumonia), ear, nasal sinus, urinary tract, skin and soft tissue.
# ========================================================================================================================
# Summary of the article -  164
# It helps to slow down the progression of moderate to severe Alzheimer's by improving memory and thinking.
# ========================================================================================================================
# Summary of the article -  165
# These are usually temporary and subside with the completion of treatment.
# ========================================================================================================================
# Summary of the article -  166
# Aceclo Tablet is not recommended if you are pregnant or breastfeeding.
# ========================================================================================================================
# Summary of the article -  167
# You should consult your doctor first if you are pregnant or breastfeeding.
# ========================================================================================================================
# Summary of the article -  168
# Avil NU 10mg Tablet belongs to a group of medicines called antihistamines.
# ========================================================================================================================
# Summary of the article -  169
# Pregnant or breastfeeding women should also consult their doctor for advice before taking this medicine.
# ========================================================================================================================
# Summary of the article -  170
# Amlip 5 Tablet belongs to a class of medicines known as a calcium channel blockers.
# ========================================================================================================================
# Summary of the article -  171
# Then repeat for the other nostril.
# ========================================================================================================================
# Summary of the article -  172
# Alupent 10mg Tablet is used to relieve symptoms of asthma and chronic obstructive pulmonary disease (COPD) such as coughing, wheezing and breathlessness.
# ========================================================================================================================
# Summary of the article -  173
# Pregnant or breastfeeding mothers should also consult their doctor before taking it.
# ========================================================================================================================
# Summary of the article -  174
# Alivher Tablet is used to treat erectile dysfunction in men.
# ========================================================================================================================
# Summary of the article -  175
# Aplazar Tablet is a nutritional supplement that is ketone derivatives of different amino acids.
# ========================================================================================================================
# Summary of the article -  176
# You should try to avoid drinking alcohol as it lowers blood glucose.
# ========================================================================================================================
# Summary of the article -  177
# These are usually temporary and subside with the completion of treatment.
# ========================================================================================================================
# Summary of the article -  178
# Amaryl MV 2mg Tablet SR belongs to a category of medicines known as anti-diabetic drugs.
# ========================================================================================================================
# Summary of the article -  179
# It relieves allergy symptoms such as runny nose, stuffy nose, sneezing, watery eyes and congestion or stuffiness.Ascoril Flu Syrup is taken with or without food in a dose and duration as advised by the doctor.
# ========================================================================================================================
# Summary of the article -  180
# It thins mucus in the nose, windpipe and lungs, making it easier to cough out.
# ========================================================================================================================
# Summary of the article -  181
# It may not be suitable.
# ========================================================================================================================
# Summary of the article -  182
# Amlopres 5 Tablet belongs to a class of medicines known as a calcium channel blockers.
# ========================================================================================================================
# Summary of the article -  183
# It’s used to treat the symptoms of asthma and chronic obstructive pulmonary disease (COPD) such as coughing, wheezing and breathlessness.Asthalin Respules is called "reliever" inhalers because they give you quick relief from breathing problems when you need it.
# ========================================================================================================================
# Summary of the article -  184
# Acitrom 3 Tablet is an oral anticoagulant which helps to prevent formation of harmful blood clots in the legs, lungs, brain and heart.
# ========================================================================================================================
# Summary of the article -  185
# Alcros 100 Capsule belongs to a group of medicines called antifungals.
# ========================================================================================================================
# Summary of the article -  186
# Alex P Syrup is used in the treatment of common cold symptoms like runny nose, stuffy nose, sneezing, watery eyes and congestion or stuffiness.
# ========================================================================================================================
# Summary of the article -  187
# Andial 2mg Tablet is used in the treatment of diarrhea.
# ========================================================================================================================
# Summary of the article -  188
# It is used to treat infections of the lungs (e.g., pneumonia), ear, nasal sinus, urinary tract, skin and soft tissue.
# ========================================================================================================================
# Summary of the article -  189
# Alfusin Tablet PR is an alpha adrenergic antagonist that is used in the treatment of benign prostatic hyperplasia.
# ========================================================================================================================
# Summary of the article -  190
# It reduces the formation of harmful blood clots in blood vessels.
# ========================================================================================================================
# Summary of the article -  191
# This medicine reduces the "bad" cholesterol (LDL) and triglycerides (fats) levels.
# ========================================================================================================================
# Summary of the article -  192
# It relieves watery eyes, runny nose, sneezing, and itching.Alerid Syrup can be taken with or without food.
# ========================================================================================================================
# Summary of the article -  193
# It minimizes oil production and helps to reduce inflammation.
# ========================================================================================================================
# Summary of the article -  194
# It works effectively to reduce abdominal pain, bloating, discomfort and cramps by relaxing the muscles of the stomach and gut.
# ========================================================================================================================
# Summary of the article -  195
# It helps in controlling the feeling of nausea and vomiting.
# ========================================================================================================================
# Summary of the article -  196
# Swallow it as a whole with water.
# ========================================================================================================================
# Summary of the article -  197
# It lowers the "bad" cholesterol (LDL), triglycerides and raises the "good" cholesterol (HDL) levels in the body.
# ========================================================================================================================
# Summary of the article -  198
# Addnok 0.2mg Tablet is used to treat moderate to severe pain and drug dependence/addiction to opioids.
# ========================================================================================================================
# Summary of the article -  199
# If this happens, inform your doctor.
# ========================================================================================================================
# Summary of the article -  200
# Most of these are temporary and usually resolve with time.
# ========================================================================================================================
# Summary of the article -  201
# Acotrust  Tablet is used in the treatment of indigestion.
# ========================================================================================================================
# Summary of the article -  202
# This will help you remember to take it.
# ========================================================================================================================
# Summary of the article -  203
# The dose and duration will depend on the severity of your condition.
# ========================================================================================================================
# Summary of the article -  204
# ...
# Summary of the article -  934
# Amlosafe 2.5 Tablet belongs to a class of medicines known as a calcium channel blockers.
# ========================================================================================================================
# Summary of the article -  935
# Your doctor will prescribe the dose most suitable for you.
# ========================================================================================================================
# Summary of the article -  936
# Astin 20 Tablet belongs to a group of medicines called statins.
# ========================================================================================================================
# Summary of the article -  937
# Inform your doctor if you are pregnant, or breastfeeding.
# ========================================================================================================================
# Summary of the article -  938
# Ascovent DX 650mg Tablet MR is used to treat and prevent symptoms of asthma and chronic obstructive pulmonary disorder (a lung disorder in which flow of air to the lung is blocked).
# ========================================================================================================================
# Summary of the article -  939
# pneumonia), ear, throat, nasal sinus, urinary tract, skin, soft tissues, bones, and joints.
# ========================================================================================================================
# Summary of the article -  940
# It is used to reduce pain and inflammation in conditions like rheumatoid arthritis, ankylosing spondylitis, and osteoarthritis.
# ========================================================================================================================
# Summary of the article -  941
# Amrosys Cream is an antifungal medication.
# ========================================================================================================================
# Summary of the article -  942
# If you experience any allergic reaction (rashes, itching, swelling, shortness of breath, etc.
# ========================================================================================================================
# Summary of the article -  943
# Acera-L Capsule SR is a prescription medicine which is used in the treatment of gastroesophageal reflux disease (acid reflux), intestinal ulcers, and irritable bowel syndrome.
# ========================================================================================================================
# Summary of the article -  944
# It is effective in infections of the respiratory tract (eg.
# ========================================================================================================================
# Summary of the article -  945
# Consult your doctor if you are breastfeeding mother.
# ========================================================================================================================
# Summary of the article -  946
# Amtas 2.5 Tablet belongs to a class of medicines known as a calcium channel blockers.
# ========================================================================================================================
# Summary of the article -  947
# These are usually temporary and subside with the completion of treatment.
# ========================================================================================================================
# Summary of the article -  948
# Amrocan Cream is an antifungal medication.
# ========================================================================================================================
# Summary of the article -  949
# It minimizes oil production and helps to reduce inflammation.
# ========================================================================================================================
# Summary of the article -  950
# Anleo-DSR Capsule is a prescription medicine used to treat gastroesophageal reflux disease (Acid reflux) and peptic ulcer disease by relieving the symptoms of acidity such as indigestion, heartburn, stomach pain, or irritation.Anleo-DSR Capsule also neutralizes the acid in the stomach and promotes easy passage of gas to reduce stomach discomfort.
# ========================================================================================================================
# Summary of the article -  951
# It helps to increase blood pressure by narrowing the blood vessels of the heart.
# ========================================================================================================================
# Summary of the article -  952
# Consult your doctor about using this medicine if you are pregnant or breastfeeding.
# ========================================================================================================================
# Summary of the article -  953
# It is used to treat various allergic conditions such as hay fever, conjunctivitis, some skin reactions such as eczema, hives, and reactions to bites and stings.
# ========================================================================================================================
# Summary of the article -  954
# pneumonia), ear, throat, nasal sinus, urinary tract, skin, soft tissues, bones, and joints.
# ========================================================================================================================
# Summary of the article -  955
# It relieves from allergic symptoms like runny nose, sneezing, and watery eyes.
# ========================================================================================================================
# Summary of the article -  956
# It is used in the treatment of psoriasis.
# ========================================================================================================================
# Summary of the article -  957
# Common side effects of this medicine include constipation, flatulence, dyspepsia, and abdominal pain.
# ========================================================================================================================
# Summary of the article -  958
# Acyclovir Eye Ointment is an antiviral medicine which treats eye infections caused by Herpes simplex virus.
# ========================================================================================================================
# Summary of the article -  959
# Alpostin 500mcg Injection is used to treat erectile dysfunction (inability to maintain erection for intercourse) in men.
# ========================================================================================================================
# Summary of the article -  960
# Pregnant or breastfeeding women should also consult their doctor for advice before taking this medicine.
# ========================================================================================================================
# Summary of the article -  961
# These are usually temporary and subside with the completion of treatment.
# ========================================================================================================================
# Summary of the article -  962
# It helps to prevent the formation of blood clots in your blood vessels.
# ========================================================================================================================
# Summary of the article -  963
# Other common side effects of this medicine include nausea, lethargy, edema, slurred speech, tremor, altered libido, and rashes.
# ========================================================================================================================
# Summary of the article -  964
# It provides relief from redness, swelling and itching.
# ========================================================================================================================
# Summary of the article -  965
# If you are pregnant or breastfeeding, ask for advice from your doctor.
# ========================================================================================================================
# Summary of the article -  966
# It thins mucus in the nose, windpipe and lungs, making it easier to cough out.
# ========================================================================================================================
# Summary of the article -  967
# AF 50 Tablet DT belongs to a group of medicines called antifungals.
# ========================================================================================================================
# Summary of the article -  968
# It should be taken orally, by swallow the tablets whole with a drink of water.
# ========================================================================================================================
# Summary of the article -  969
# This medicine can lead to weight gain and may increase your blood sugar and cholesterol levels.
# ========================================================================================================================
# Summary of the article -  970
# Arip MT 10 Tablet is an antipsychotic medicine.
# ========================================================================================================================
# Summary of the article -  971
# Apraize 10 Tablet is used in the treatment of moderate to severe plaque psoriasis which is a type of skin condition.
# ========================================================================================================================
# Summary of the article -  972
# Aloederm F Cream is an antibiotic.
# ========================================================================================================================
# Summary of the article -  973
# It is used to treat infections of the lungs (e.g., pneumonia), ear, nasal sinus, urinary tract, skin and soft tissue.
# ========================================================================================================================
# Summary of the article -  974
# It is a natural female hormone important for regulating ovulation (release of an egg from a woman's ovary) and menstruation.
# ========================================================================================================================
# Summary of the article -  975
# This medicine can lead to weight gain and may increase your blood sugar and cholesterol levels.
# ========================================================================================================================
# Summary of the article -  976
# Arzu 10 Tablet is an antipsychotic medicine.
# ========================================================================================================================
# Summary of the article -  977
# It is for external use only.
# ========================================================================================================================
# Summary of the article -  978
# Other side effects nausea, diarrhea, headache, and altered blood lipids.
# ========================================================================================================================
# Summary of the article -  979
# It works by protecting the nerve fibers against damage, repairing the damaged nerves.
# ========================================================================================================================
# Summary of the article -  980
# Allerfex 120mg Tablet belongs to a group of medicines called antihistamines.
# ========================================================================================================================
# Summary of the article -  981
# Alday Duo 5mg/10mg Tablet is a combination medicine used in the treatment of allergic symptoms such as runny nose, stuffy nose, sneezing, itching, swelling, watery eyes and congestion or stuffiness.
# ========================================================================================================================
# Summary of the article -  982
# It should not be chewed or crushed.
# ========================================================================================================================
# Summary of the article -  983
# It is an effective appetite stimulant.
# ========================================================================================================================
# Summary of the article -  984
# These are usually temporary and subside with the completion of treatment.
# ========================================================================================================================
# Summary of the article -  985
# It should be taken with or without food preferably in the morning, to avoid frequent urination at night.
# ========================================================================================================================
# Summary of the article -  986
# It may not be suitable.
# ========================================================================================================================
# Summary of the article -  987
# If these bother you, or appear serious, let your doctor know.
# ========================================================================================================================
# Summary of the article -  988
# It is used to treat leprosy and acne.
# ========================================================================================================================
# Summary of the article -  989
# It is used to treat infections of the lungs (e.g., pneumonia), ear, nasal sinus, urinary tract, skin and soft tissue.
# ========================================================================================================================
# Summary of the article -  990
# It is used to treat infections of the lungs (e.g., pneumonia), ear, nasal sinus, urinary tract, skin, and soft tissue.
# ========================================================================================================================
# Summary of the article -  991
# It can be taken with a meal or on an empty stomach.
# ========================================================================================================================
# Summary of the article -  992
# Common side effects of this medicine include constipation, flatulence, dyspepsia, and abdominal pain.
# ========================================================================================================================
# Summary of the article -  993
# It reduces pain and swelling by reducing inflammation.
# ========================================================================================================================
# Summary of the article -  994
# Inform your doctor if you are pregnant, or breastfeeding.
# ========================================================================================================================
# Summary of the article -  995
# It is prescribed to treat various types of bacterial infections.
# ========================================================================================================================
# Summary of the article -  996
# Swallow it as a whole,  do not crush, chew, break, or open them.
# ========================================================================================================================
# Summary of the article -  997
# Swallow the tablets whole with a drink of water.
# ========================================================================================================================
# Summary of the article -  998
# However, it is not recommended while breastfeeding.
# ========================================================================================================================
# Summary of the article -  999
# Consult your doctor If any of these bother you, or get worse, or do not go away.
# ========================================================================================================================
# Summary of the article -  1000
# It is known as a calcium channel blocker.
# ========================================================================================================================
# **************************************** The process has been completed successfully ****************************************

# %%
summary_table = pd.DataFrame(list(summary_dictionary.items()),columns = ['TEST DATASET','Summary'])

# %%
data_table = pd.DataFrame(list(text_dictionary.items()),columns = ['TEST DATASET','Introduction'])

# %%
# Combining the findings into the table
result  = pd.concat([data_table , summary_table['Summary']], axis = 1 , sort = False)
result
# Out:
#      TEST DATASET                                       Introduction  \
# 0               1  Acnesol Gel is an antibiotic that fights bacte...
# 1               2  Ambrodil Syrup is used for treating various re...
# 2               3  Augmentin 625 Duo Tablet is a penicillin-type ...
# 3               4  Azithral 500 Tablet is an antibiotic used to t...
# 4               5  Alkasol Oral Solution is a medicine used in th...
# ..            ...                                                ...
# 995           996  Azapure Tablet belongs to a group of medicines...
# 996           997  Arimidex 1mg Tablet  is used alone or with oth...
# 997           998  Arpimune ME 100mg Capsule is used to prevent y...
# 998           999  Amlodac CH Tablet is a combination medicine us...
# 999          1000  Angizem CD 120 Capsule ER is used to treat ang...
#
#                                                Summary
# 0    Acnesol Gel is an antibiotic that fights bacte...
# 1    Ambrodil Syrup is used for treating various re...
# 2    It is used to treat infections of the lungs (e...
# 3    These are usually temporary and subside with t...
# 4    This will prevent you from getting an upset st...
# ..                                                 ...
# 995  Swallow it as a whole,  do not crush, chew, br...
# 996   Swallow the tablets whole with a drink of water.
# 997  However, it is not recommended while breastfee...
# 998  Consult your doctor If any of these bother you...
# 999          It is known as a calcium channel blocker.
#
# [1000 rows x 3 columns]

# %%
# Saving it to a file (remove the '#' to save)
result.to_csv(r"C:\Users\Vaishaali\Desktop\SF.csv")
